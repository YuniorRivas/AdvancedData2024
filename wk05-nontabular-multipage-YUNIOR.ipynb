# %% [markdown]
# ## Scraping non-tabular, multipage sites
# Scrape the top 500 <a href="https://bestsellingalbums.org/decade/2010">best-selling albums of the 2010's</a>. Your data must include the following datapoints:
#
# - Name of album
# - Name of artist
# - Number of albums sold
# - The link to the page that breaks down sales by country (found by clicking album title)

# %%
## create cells as needed
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
link_fl = []
first_link = 'https://bestsellingalbums.org/decade/2010'
link_fl.append(first_link)

# %%
link = 'https://bestsellingalbums.org/decade/2010-'

# %%
for link_number in range(2, 11):
    full_link = f"{link}{link_number}"
    link_fl.append(full_link)
    print(full_link)
# Out:
# https://bestsellingalbums.org/decade/2010-2
# https://bestsellingalbums.org/decade/2010-3
# https://bestsellingalbums.org/decade/2010-4
# https://bestsellingalbums.org/decade/2010-5
# https://bestsellingalbums.org/decade/2010-6
# https://bestsellingalbums.org/decade/2010-7
# https://bestsellingalbums.org/decade/2010-8
# https://bestsellingalbums.org/decade/2010-9
# https://bestsellingalbums.org/decade/2010-10

# %%
link_fl
# Out:
# ['https://bestsellingalbums.org/decade/2010',
#  'https://bestsellingalbums.org/decade/2010-2',
#  'https://bestsellingalbums.org/decade/2010-3',
#  'https://bestsellingalbums.org/decade/2010-4',
#  'https://bestsellingalbums.org/decade/2010-5',
#  'https://bestsellingalbums.org/decade/2010-6',
#  'https://bestsellingalbums.org/decade/2010-7',
#  'https://bestsellingalbums.org/decade/2010-8',
#  'https://bestsellingalbums.org/decade/2010-9',
#  'https://bestsellingalbums.org/decade/2010-10']

# %%
top_albums = []

# %%
for link in link_fl:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    albums = soup.find_all('div', class_='album_card')
    print(f"Scraped page: {link}, Total albums collected so far: {len(top_albums)}")
# Out:
# Scraped page: https://bestsellingalbums.org/decade/2010, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-2, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-3, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-4, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-5, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-6, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-7, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-8, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-9, Total albums collected so far: 0
# Scraped page: https://bestsellingalbums.org/decade/2010-10, Total albums collected so far: 0

# %%
for album in albums:
    album_title = album.find('div', class_='album').text.strip()
    artist = album.find('div', class_='artist').text.strip()
    total_sales = album.find('div', class_='sales').text.strip()
    sales_number = ''.join(filter(str.isdigit, total_sales))
    full_album_link = f"https://bestsellingalbums.org{sales_by_country}"
    top_albums.append({
        'Album Title': album_title,
        'Artist': artist,
        'Total Sales': total_sales,
        'Sales By Country': sales_by_country
    })

# %%
df = pd.DataFrame(top_albums)

# %%
df
# Out:
#                                           Album Title                  Artist  \
# 0                                        I AM > I WAS               21 SAVAGE
# 1                                 LIFE OF A DARK ROSE               LIL SKIES
# 2                                    4 YOUR EYEZ ONLY                 J. COLE
# 3                              LATE NIGHTS: THE ALBUM                 JEREMIH
# 4                                          GET CLOSER             KEITH URBAN
# 5   IN AND OUT OF CONSCIOUSNESS - GREATEST HITS 19...         ROBBIE WILLIAMS
# 6                                TANGLED (SOUNDTRACK)             ALAN MENKEN
# 7                                         DRIP HARDER        GUNNA & LIL BABY
# 8                                        JUNGLE RULES          FRENCH MONTANA
# 9                                              H.E.R.                  H.E.R.
# 10                                         LOVE STUFF               ELLE KING
# 11                     COLE WORLD: THE SIDELINE STORY                 J. COLE
# 12        MTV UNPLUGGED - LIVE AUS DEM HOTEL ATLANTIK          UDO LINDENBERG
# 13                                     WRAPPED IN RED          KELLY CLARKSON
# 14                                         ISSA ALBUM               21 SAVAGE
# 15                                         REFLECTION           FIFTH HARMONY
# 16                                          WOODSTOCK       PORTUGAL. THE MAN
# 17                        SAME TRAILER DIFFERENT PARK         KACEY MUSGRAVES
# 18                    OUTLAW GENTLEMEN & SHADY LADIES                 VOLBEAT
# 19                                         CRY PRETTY        CARRIE UNDERWOOD
# 20                                         DAN + SHAY              DAN + SHAY
# 21                                      REARVIEW TOWN            JASON ALDEAN
# 22                                         EXPERIMENT              KANE BROWN
# 23                                  THE BIGGER ARTIST  A BOOGIE WIT DA HOODIE
# 24                                        BRETT YOUNG             BRETT YOUNG
# 25                                           FREUDIAN           DANIEL CAESAR
# 26                                       LIFE CHANGES            THOMAS RHETT
# 27                                      ANYTHING GOES    FLORIDA GEORGIA LINE
# 28                                           JOURNALS           JUSTIN BIEBER
# 29                                       O HOLY NIGHT          JACKIE EVANCHO
# 30                                     THE BAND PERRY          THE BAND PERRY
# 31                                              BIRDY                   BIRDY
# 32                                     HELENE FISCHER          HELENE FISCHER
# 33                                         SCHWERELOS             ANDREA BERG
# 34                                      PLAYBOI CARTI           PLAYBOI CARTI
# 35                                 KALEIDOSCOPE DREAM                  MIGUEL
# 36                                          ABENTEUER             ANDREA BERG
# 37                                    NUMBER ONE HITS              TIM MCGRAW
# 38                                MEGALITHIC SYMPHONY              AWOLNATION
# 39                  GROWING WILD - EP4 长 [3 track EP]         CHRIS LEE (李宇春)
# 40                             A LOVE LETTER TO YOU 4            TRIPPIE REDD
# 41                                        STORYTELLER        CARRIE UNDERWOOD
# 42                                           ENSEMBLE            KENDJI GIRAC
# 43                                          GET WEIRD              LITTLE MIX
# 44                           GREATEST HITS: DECADE #1        CARRIE UNDERWOOD
# 45                                     UNDER PRESSURE                   LOGIC
# 46                                THE STRANGE CASE OF               HALESTORM
# 47                                            UNCAGED          ZAC BROWN BAND
# 48                                             FUTURE                  FUTURE
# 49                                             HNDRXX                  FUTURE
#
#          Total Sales                           Sales By Country
# 0   Sales: 1,110,000  https://bestsellingalbums.org/album/16039
# 1   Sales: 1,110,000  https://bestsellingalbums.org/album/16039
# 2   Sales: 1,110,000  https://bestsellingalbums.org/album/16039
# 3   Sales: 1,110,000  https://bestsellingalbums.org/album/16039
# 4   Sales: 1,110,000  https://bestsellingalbums.org/album/16039
# 5   Sales: 1,104,500  https://bestsellingalbums.org/album/16039
# 6   Sales: 1,102,208  https://bestsellingalbums.org/album/16039
# 7   Sales: 1,100,000  https://bestsellingalbums.org/album/16039
# 8   Sales: 1,100,000  https://bestsellingalbums.org/album/16039
# 9   Sales: 1,100,000  https://bestsellingalbums.org/album/16039
# 10  Sales: 1,100,000  https://bestsellingalbums.org/album/16039
# 11  Sales: 1,100,000  https://bestsellingalbums.org/album/16039
# 12  Sales: 1,100,000  https://bestsellingalbums.org/album/16039
# 13  Sales: 1,095,000  https://bestsellingalbums.org/album/16039
# 14  Sales: 1,090,000  https://bestsellingalbums.org/album/16039
# 15  Sales: 1,090,000  https://bestsellingalbums.org/album/16039
# 16  Sales: 1,087,500  https://bestsellingalbums.org/album/16039
# 17  Sales: 1,087,000  https://bestsellingalbums.org/album/16039
# 18  Sales: 1,085,000  https://bestsellingalbums.org/album/16039
# 19  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 20  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 21  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 22  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 23  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 24  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 25  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 26  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 27  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 28  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 29  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 30  Sales: 1,080,000  https://bestsellingalbums.org/album/16039
# 31  Sales: 1,077,500  https://bestsellingalbums.org/album/16039
# 32  Sales: 1,075,000  https://bestsellingalbums.org/album/16039
# 33  Sales: 1,075,000  https://bestsellingalbums.org/album/16039
# 34  Sales: 1,070,949  https://bestsellingalbums.org/album/16039
# 35  Sales: 1,070,000  https://bestsellingalbums.org/album/16039
# 36  Sales: 1,070,000  https://bestsellingalbums.org/album/16039
# 37  Sales: 1,067,000  https://bestsellingalbums.org/album/16039
# 38  Sales: 1,065,000  https://bestsellingalbums.org/album/16039
# 39  Sales: 1,064,211  https://bestsellingalbums.org/album/16039
# 40  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 41  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 42  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 43  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 44  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 45  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 46  Sales: 1,060,000  https://bestsellingalbums.org/album/16039
# 47  Sales: 1,055,000  https://bestsellingalbums.org/album/16039
# 48  Sales: 1,050,371  https://bestsellingalbums.org/album/16039
# 49  Sales: 1,050,000  https://bestsellingalbums.org/album/16039

# %%
len(df)
# Out:
# 50

# %%
df.to_csv('top_500_albums_2010s_first_10_pages.csv', index=False)
